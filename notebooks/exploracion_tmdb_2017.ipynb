# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.7-cp314-cp314-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp314-cp314-macosx_10_13_universal2.whl.metadata (112 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-12.0.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.7-cp314-cp314-macosx_11_0_arm64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.60.1-cp314-cp314-macosx_10_13_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.9-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Using cached pillow-12.0.0-cp314-cp314-macosx_11_0_arm64.whl (4.7 MB)
# ...

# %%
import pandas as pd

df = pd.read_csv("../data_raw/tmdb_details_2017.csv")

df.head()
# Out:
#    tmdb_id    imdb_id                                 title  \
# 0   346364  tt1396484                                    It
# 1   354912  tt2380307                                  Coco
# 2   479366  tt6339230                         Deadly Exposé
# 3   482600        NaN                          Japanese Mom
# 4   488968        NaN  Sree Hari Hara Sudhan Swami Ayyappan
#
#                          original_title  \
# 0                                    It
# 1                                  Coco
# 2                         Deadly Exposé
# 3                                 일본 엄마
# 4  Sree Hari Hara Sudhan Swami Ayyappan
#
#                                             overview release_date  runtime  \
# 0  In a small town in Maine, seven children known...   2017-09-06      135
# 1  Despite his family’s baffling generations-old ...   2017-10-27      105
# 2  When several carnal murders in a small beach t...   2017-05-01       87
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9998 entries, 0 to 9997
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tmdb_id                9998 non-null   int64
#  1   imdb_id                8301 non-null   object
#  2   title                  9998 non-null   object
#  3   original_title         9998 non-null   object
#  4   overview               9367 non-null   object
#  5   release_date           9998 non-null   object
#  6   runtime                9998 non-null   int64
#  7   budget                 9998 non-null   int64
#  8   revenue                9998 non-null   int64
#  9   adult                  9998 non-null   bool
#  10  genres                 9021 non-null   object
#  11  production_countries   8042 non-null   object
#  12  production_companies   6588 non-null   object
#  13  popularity             9998 non-null   float64
# ...

# %%
df.isna().mean().sort_values(ascending=False).head(20)
# Out:
# belongs_to_collection    0.929886
# production_companies     0.341068
# production_countries     0.195639
# imdb_id                  0.169734
# genres                   0.097720
# overview                 0.063113
# original_language        0.000000
# vote_average             0.000000
# vote_count               0.000000
# popularity               0.000000
# tmdb_id                  0.000000
# revenue                  0.000000
# budget                   0.000000
# runtime                  0.000000
# release_date             0.000000
# original_title           0.000000
# title                    0.000000
# adult                    0.000000
# dtype: float64

# %%
df[['budget', 'revenue', 'runtime', 'vote_count']].describe()
# Out:
#              budget       revenue      runtime    vote_count
# count  9.998000e+03  9.998000e+03  9998.000000   9998.000000
# mean   1.133918e+06  3.546233e+06    69.175135    123.565813
# std    1.032212e+07  4.275366e+07    47.542938    954.048898
# min    0.000000e+00  0.000000e+00     0.000000      0.000000
# 25%    0.000000e+00  0.000000e+00    18.000000      0.000000
# 50%    0.000000e+00  0.000000e+00    84.000000      2.000000
# 75%    0.000000e+00  0.000000e+00    99.000000     15.000000
# max    3.000000e+08  1.332699e+09   950.000000  22620.000000

# %%
df['genres'].value_counts().head(20)
# Out:
# genres
# Drama                 1514
# Documentary           1030
# Comedy                 800
# Horror                 333
# Comedy, Drama          228
# Drama, Romance         171
# Music                  160
# Drama, Comedy          148
# Romance                130
# Romance, Drama         124
# Thriller               112
# Comedy, Romance        103
# Animation               94
# Horror, Thriller        88
# Drama, Thriller         84
# Science Fiction         78
# Documentary, Music      64
# Action                  64
# Romance, Comedy         57
# Family                  53
# Name: count, dtype: int64

# %%
df.sort_values("revenue", ascending=False).head(20)
# Out:
#       tmdb_id    imdb_id                                             title  \
# 225    181808  tt2527336                          Star Wars: The Last Jedi
# 10     321612  tt2771200                              Beauty and the Beast
# 49     337339  tt4630562                           The Fate of the Furious
# 116    324852  tt3469046                                   Despicable Me 3
# 187    353486  tt2283362                    Jumanji: Welcome to the Jungle
# 9      315635  tt2250912                            Spider-Man: Homecoming
# 1940   452557  tt7131870                                    Wolf Warrior 2
# 28     283995  tt3896198                    Guardians of the Galaxy Vol. 2
# 41     284053  tt3501632                                    Thor: Ragnarok
# 17     297762  tt0451279                                      Wonder Woman
# 1      354912  tt2380307                                              Coco
# ...

# %%
df.plot.scatter(x="budget", y="revenue", alpha=0.3)
# Out:
# <Axes: xlabel='budget', ylabel='revenue'>
