# %%
import pandas as pd

df = pd.read_csv("../data_raw/tmdb_movies_2020.csv")
df.head()
# Out:
#    tmdb_id                                              title  \
# 0   726703                                             Waimea
# 1   635302  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...
# 2   744940                                 Homemade Christmas
# 3   660632                                 Shattered Memories
# 4   644090                                   Love, Guaranteed
#
#        original_title                                           overview  \
# 0              Waimea  Rick and Vivian O'Neill struggle with the grea...
# 1      劇場版「鬼滅の刃」無限列車編  Tanjiro Kamado, joined with Inosuke Hashibira,...
# 2  Homemade Christmas  Every year, Megan, an ambitious young woman us...
# 3  Shattered Memories  Kelly's life is upended when she wakes up in t...
# 4    Love, Guaranteed  A lawyer takes on a new client that wants to s...
#
#   release_date original_language  popularity  vote_count  vote_average  \
# 0   2020-07-15                en     19.2017           0         0.000
# ...
